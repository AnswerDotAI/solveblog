# %% [raw]
# ---
# title: Test Dialog Post
# date: 2026-04-02
# tags:
#   - test
# ---

# %% [markdown]
# Hello world! This is my first blogpost on `solveblog`.

# %% [markdown]
# ## Solveblog supports solveit prompt cells

# %% [markdown]
# Hey SolveIt! Ths is going to be my first blogpost!
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Hey, that's exciting! 🎉 Congrats on starting your first blog post!
#
# I can see you've already got your frontmatter set up with a title, date, excerpt, and tags — nice start! What's your blog post going to be about?

# %% [markdown]
# Ill showcase the nice markup features we have.
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Great idea, show me what you got!

# %% [markdown]
# ## Markdown Formatting Showcase
#
# You can write in **bold**, *italics*, or ***both***. ~~Strikethrough~~ works too.
#
# > Blockquotes are great for highlighting key ideas or quotations.
#
# Here's an unordered list:
# - First item
# - Second item
#   - Nested item
#
# And an ordered list:
# 1. Step one
# 2. Step two
# 3. Step three
#
# Inline `code` looks like this, and links look like [this](https://example.com).
#
# ---
#
# ### HTML extras
#
# <details>
# <summary>Click to expand a collapsible section!</summary>
#
# This content is hidden until the reader clicks. Handy for spoilers or long output.
#
# </details>
#
# <mark>Highlighted text</mark> can draw attention to something important.
#
# You can also use HTML tables for more control:
#
# <table>
# <tr><th>Feature</th><th>Supported?</th></tr>
# <tr><td>Markdown</td><td>✅</td></tr>
# <tr><td>HTML</td><td>✅</td></tr>
# <tr><td>Emoji</td><td>🎉</td></tr>
# </table>

# %% [markdown]
# ## Images

# %% [markdown]
# Here's a picture of Jeremy, it's included via URL.
#
# ![](https://solve.it.com/static/imgs/j.jpg)

# %% [markdown]
# Here's a picture of Eric, it's included via copy paste:
#
# ![image.png](attachment:9e6200e0-73bf-46d4-928b-bf0d674c7511)

# %% [markdown]
# And this picture is included as a local file:
#
# ![](puppy.jpg)

# %% [markdown]
# ## Tables

# %%
import pandas as pd

pd.DataFrame({
    'Planet': ['Mercury', 'Venus', 'Earth'],
    'Moons': [0, 0, 1],
    'Radius (km)': [2440, 6052, 6371]
})
# Out:
#     Planet  Moons  Radius (km)
# 0  Mercury      0         2440
# 1    Venus      0         6052
# 2    Earth      1         6371

# %% [markdown]
# ## Code

# %%
def greet(nm:str):
    return f"Hello {nm}"

greet("Jack")
# Out:
# 'Hello Jack'

# %%
print('Hello from stdout!')
print('Line 2 of output')
# Out:
# Hello from stdout!
# Line 2 of output

# %%
import sys
print('Warning: something happened', file=sys.stderr)

# %%
1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 1/0
#
# ZeroDivisionError: division by zero

# %%
import numpy as np, matplotlib.pyplot as plt
t = np.linspace(0, 20*np.pi, 10000)
plt.plot(np.cos(t)+np.cos(6.3*t)/2, np.sin(t)+np.sin(6.3*t)/2, lw=0.5)
plt.axis('equal'); plt.axis('off'); plt.show()
