# %% [markdown]
# <img src="/public/pages/portrait.svg" alt="portrait" class="w-2/5 md:w-1/3 float-left mr-4 md:mr-6 mb-4 rounded-lg">

# %% [markdown]
# Tell us who you are and what you're interested in :-)
